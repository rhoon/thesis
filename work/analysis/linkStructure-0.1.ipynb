# %%
import json
from pprint import pprint

with open('data/dada-mapsTo.json') as data_file:
    mapsTo_data = json.load(data_file)
    
# pprint(mapsTo_data)

#structure notes
# url
# metaData

print(mapsTo_data[2]['mapsFrom'])
# Out:
# ['Dada', 'Edvard_Munch', 'Erik_Satie', 'Franz_Kafka', 'The_Metamorphosis', 'Georges_Braque', 'History_of_painting', 'Impressionism', 'January_22', 'Juan_Gris', 'Modernism', 'Minimalism', 'November_30', 'Normandy', 'Postmodernism', 'Pablo_Picasso', 'Paul_C%C3%A9zanne', 'Robert_Musil', 'Rainer_Maria_Rilke', 'Surrealism', 'Thomas_Mann', 'Typography', 'Vincent_van_Gogh', 'Wassily_Kandinsky', '1930s', '1920s', '1953', '1879', 'Tristan_Tzara', 'Cubism', 'Marcel_Duchamp', 'New_materials_in_20th-century_art', 'Pierrot', 'Gertrude_Stein', 'Guillaume_Apollinaire', 'Georges_Seurat', 'Man_Ray', 'Fernand_L%C3%A9ger', 'Montmartre_Cemetery', 'Henri_de_Toulouse-Lautrec', 'Paul_Gauguin', 'Remodernism', 'Alice_Prin', 'Avant-garde', 'Paul_Klee', 'Amiens', 'Fluxus', 'Symbolism_(arts)', 'Found_object', 'Aleatoric_music', 'Expressionism', 'Pop_art', 'Peggy_Guggenheim_Collection', 'Abstract_expressionism', 'Roger_D%C3%A9sormi%C3%A8re', 'Modern_art', 'Post-Impressionism', 'Les_Nabis', 'Odilon_Redon', 'Point
# ...

# %%
print(mapsTo_data[2]['mapsTo'])
# Out:
# ['File:Francis_Picabia,_1919,_Danse_de_Saint-Guy,_The_Little_Review,_Picabia_number,_Autumn_1922.jpg', 'Paris', 'Painting', 'Cubism', 'Dada', 'Surrealism', 'Avant-garde', 'Impressionism', 'Pointillism', 'Abstract_art', 'United_States', 'France', 'File:Francis_Picabia,_1912,_La_Source,_The_Spring,_oil_on_canvas,_249.6_x_249.3_cm,_Museum_of_Modern_Art,_New_York._Exhibited,_1912_Salon_d%27Automne,_Paris.jpg', 'Museum_of_Modern_Art', 'Cuba', 'Galicia_(Spain)', 'Fernand_Cormon', '%C3%89cole_nationale_sup%C3%A9rieure_des_arts_d%C3%A9coratifs', 'File:Picabia_Machine_Turn.jpg', 'National_Gallery_of_Art', 'Vincent_van_Gogh', 'Toulouse-Lautrec', 'File:Francis_Picabia,_1913,_Udnie_(Young_American_Girl,_The_Dance),_oil_on_canvas,_290_x_300_cm,_Mus%C3%A9e_National_d%E2%80%99Art_Moderne,_Centre_Georges_Pompidou,_Paris..jpg', 'Mus%C3%A9e_National_d%27Art_Moderne', 'Centre_Georges_Pompidou', 'Alfred_Sisley', 'Claude_Monet', 'Paul_Signac', 'Section_d%27Or', 'Puteaux_Group', 'Jacques_Villon', 'Puteaux
# ...

# %%
print(json.dumps(mapsTo_data[1], indent=4, sort_keys=True))
# Out:
# {
#     "mapsFrom": [
#         "Dada"
#     ],
#     "url": "File:Francis_Picabia,_Dame!_Illustration_for_the_cover_of_the_periodical_Dadaphone_n._7,_Paris,_March_1920.jpg"
# }

# %%
for obj in mapsTo_data:
    print('----->'+obj["url"])
    
    if hasattr(obj, 'mapsTo'):
        print('true')
    else:
        print('false')
#     for link in obj["mapsTo"]:
#         print(link)
# Out:
# ----->Dada_(disambiguation)
# false
# ----->File:Francis_Picabia,_Dame!_Illustration_for_the_cover_of_the_periodical_Dadaphone_n._7,_Paris,_March_1920.jpg
# false
# ----->Francis_Picabia
# false
# ----->Art_movement
# false
# ----->Avant-garde
# false
# ----->Z%C3%BCrich
# false
# ----->Switzerland
# false
# ----->Cabaret_Voltaire_(Zurich)
# false
# ----->New_York_Dada
# false
# ----->World_War_I
# false
# ----->Logic
# false
# ----->Reason
# false
# ----->Aestheticism
# false
# ----->Capitalist_society
# false
# ----->Nonsense
# false
# ----->Irrationality
# false
# ----->Anti-bourgeois
# false
# ----->Cut-up_technique
# false
# ----->Far-left_politics
# false
# ----->File:Dada1.jpg
# false
# ----->Collage
# false
# ----->Sound_poetry
# false
# ----->Tristan_Tzara
# false
# ----->Anti-art
# false
# ----->Marcel_Duchamp
# false
# ----->Cubism
# false
# ----->Abstract_art
# false
# ----->Futurism
# false
# ----->Expressionism
# false
# ----->Ubu_Roi
# false
# ----->Alfred_Jarry
# ...

# %%
i
# Out:
# 226
