# %%
import json
from pprint import pprint

with open('data/dada-mapsTo.json') as data_file:
    mapsTo_data = json.load(data_file)
    
# pprint(mapsTo_data)

#structure notes
# url
# metaData

print(mapsTo_data[2]['mapsFrom'])
# Out:
# ['Dada', 'Edvard_Munch', 'Erik_Satie', 'Franz_Kafka', 'The_Metamorphosis', 'Georges_Braque', 'History_of_painting', 'Impressionism', 'January_22', 'Juan_Gris', 'Modernism', 'Minimalism', 'November_30', 'Normandy', 'Postmodernism', 'Pablo_Picasso', 'Paul_C%C3%A9zanne', 'Robert_Musil', 'Rainer_Maria_Rilke', 'Surrealism', 'Thomas_Mann', 'Typography', 'Vincent_van_Gogh', 'Wassily_Kandinsky', '1930s', '1920s', '1953', '1879', 'Tristan_Tzara', 'Cubism', 'Marcel_Duchamp', 'New_materials_in_20th-century_art', 'Pierrot', 'Gertrude_Stein', 'Guillaume_Apollinaire', 'Georges_Seurat', 'Man_Ray', 'Fernand_L%C3%A9ger', 'Montmartre_Cemetery', 'Henri_de_Toulouse-Lautrec', 'Paul_Gauguin', 'Remodernism', 'Alice_Prin', 'Avant-garde', 'Paul_Klee', 'Amiens', 'Fluxus', 'Symbolism_(arts)', 'Found_object', 'Aleatoric_music', 'Expressionism', 'Pop_art', 'Peggy_Guggenheim_Collection', 'Abstract_expressionism', 'Roger_D%C3%A9sormi%C3%A8re', 'Modern_art', 'Post-Impressionism', 'Les_Nabis', 'Odilon_Redon', 'Point
# ...

# %%
print(mapsTo_data[3])
# Out:
# {'metaData': {'subclass of': ['cultural movement'], 'Commons category': ['Art movements'], "topic's main category": ['Category:Art movements']}, 'mapsTo': ['File:Lascaux2.jpg', 'History_of_art', 'Prehistoric_art', 'Ancient_art', 'Art_of_Europe', 'History_of_Asian_art', 'Islamic_art', 'History_of_painting', 'Western_painting', 'Art_history', 'Template:History_of_art_sidebar', 'Template_talk:History_of_art_sidebar', 'Modern_art', 'Avant-garde', 'Modernism', 'Postmodern_art', 'Contemporary_art', 'Late_modernism', 'Art_manifesto', 'Art_critic', 'Visual_arts', 'Visual_art', 'Architecture', 'Literature', 'Music', 'Genre', 'Fashion', 'Cultural_movement', 'Cubism', 'Futurism_(art)', 'File:Jacques-Louis_David_006.jpg', 'Jacques-Louis_David', 'The_Coronation_of_Napoleon', 'Mus%C3%A9e_du_Louvre', 'History_painting', 'File:Eug%C3%A8ne_Delacroix_-_La_libert%C3%A9_guidant_le_peuple.jpg', 'Eug%C3%A8ne_Delacroix', 'Liberty_Leading_the_People', 'Romanticism', 'File:The_Course_of_Empire_The_Savage_Sta
# ...

# %%
print(json.dumps(mapsTo_data[25], indent=4, sort_keys=True))
# Out:
# {
#     "mapsFrom": [
#         "Art",
#         "Artist",
#         "Art_Deco",
#         "Aesthetics",
#         "Alberto_Giacometti",
#         "Brazil",
#         "Bauhaus",
#         "Baroque",
#         "Colombia",
#         "Czech_Republic",
#         "Cyberpunk",
#         "Cultural_movement",
#         "Columbus,_Ohio",
#         "Camouflage",
#         "Catalonia",
#         "Dada",
#         "Edvard_Munch",
#         "Erik_Satie",
#         "Franz_Kafka",
#         "The_Metamorphosis",
#         "Filippo_Tommaso_Marinetti",
#         "Georges_Braque",
#         "History_of_painting",
#         "I._M._Pei",
#         "Impressionism",
#         "Interdisciplinarity",
#         "Juan_Gris",
#         "Jacob_Lawrence",
#         "Jackson_Pollock",
#         "Kurt_Schwitters",
#         "Kazimir_Malevich",
#         "Le_Corbusier",
#         "Index_of_philosophy_articles_(A%E2%80%93C)",
#         "Lyonel_Feininger",
#         "Modernism",
#         "Mannerism",
# ...

# %%
# Out:
# ----->Dada_(disambiguation)
# false
# ----->File:Francis_Picabia,_Dame!_Illustration_for_the_cover_of_the_periodical_Dadaphone_n._7,_Paris,_March_1920.jpg
# false
# ----->Francis_Picabia
# false
# ----->Art_movement
# false
# ----->Avant-garde
# false
# ----->Z%C3%BCrich
# false
# ----->Switzerland
# false
# ----->Cabaret_Voltaire_(Zurich)
# false
# ----->New_York_Dada
# false
# ----->World_War_I
# false
# ----->Logic
# false
# ----->Reason
# false
# ----->Aestheticism
# false
# ----->Capitalist_society
# false
# ----->Nonsense
# false
# ----->Irrationality
# false
# ----->Anti-bourgeois
# false
# ----->Cut-up_technique
# false
# ----->Far-left_politics
# false
# ----->File:Dada1.jpg
# false
# ----->Collage
# false
# ----->Sound_poetry
# false
# ----->Tristan_Tzara
# false
# ----->Anti-art
# false
# ----->Marcel_Duchamp
# false
# ----->Cubism
# false
# ----->Abstract_art
# false
# ----->Futurism
# false
# ----->Expressionism
# false
# ----->Ubu_Roi
# false
# ----->Alfred_Jarry
# ...

# %%
i
# Out:
# 226
