# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import json
from pprint import pprint

with open('data/mapsFrom_Crawl.json') as data_file:    
    mapsFrom = json.load(data_file)
    
with open('data/mapsTo_Crawl.json') as data_file:
    mapsTo = json.load(data_file)
    
with open('data/d2-combined-roots.json') as data_file:
    d2 = json.load(data_file)
    
with open('data/Dada-update0.json') as data_file:
    dada = json.load(data_file)
    
with open('data/prototypeData-d1-d2.json') as data_file:
    d1d2 = json.load(data_file)
    
with open('data/forceChart-2.json') as data_file:
    d1d2 = json.load(data_file)

# %%
len(mapsFrom) + len(d2) + len(mapsTo)
# Out:
# 1512

# %%
# double check to see if d1d2 has Dada (it should not)
check = [x for x in d1d2 if x['url'] == 'Exploits_and_Opinions_of_Dr._Faustroll,_Pataphysician']
check
# Out:
# []

# %%
# Out:
#   File "<ipython-input-24-24b52cf14557>", line 12
#     lambda (u, d), o : (u.union([o]), d.union(u.intersection([o]))),
#            ^
# SyntaxError: invalid syntax

# %%
mapsFrom[0]['url']
# Out:
# 'Alfred_Jarry'

# %%
dada
# Out:
# [{'distance': 1,
#   'image': '//upload.wikimedia.org/wikipedia/en/thumb/2/2b/Francis_Picabia%2C_Dame%21_Illustration_for_the_cover_of_the_periodical_Dadaphone_n._7%2C_Paris%2C_March_1920.jpg/220px-Francis_Picabia%2C_Dame%21_Illustration_for_the_cover_of_the_periodical_Dadaphone_n._7%2C_Paris%2C_March_1920.jpg',
#   'mapsFrom': ['Allen_Ginsberg',
#    'Alfred_Jarry',
#    'Art_Deco',
#    'Aesthetics',
#    'Alban_Berg',
#    'Bauhaus',
#    'Baroque',
#    'Brion_Gysin',
#    'B%C3%A9la_Bart%C3%B3k',
#    'Charlie_Chaplin',
#    'Cyberpunk',
#    'Cut-up_technique',
#    'Dmitri_Shostakovich',
#    'E._E._Cummings',
#    'Erik_Satie',
#    'Cinema_of_Germany',
#    'Frank_Zappa',
#    'Film_editing',
#    'Franz_Kafka',
#    'The_Metamorphosis',
#    'German_literature',
#    'Henri_Chopin',
#    'Impressionism_in_music',
#    'Individualist_anarchism',
#    'Impressionism',
#    'James_Joyce',
#    'Kurt_Schwitters',
#    'Modernism',
#    'Marshall_McLuhan',
#    'Mannerism',
# ...
